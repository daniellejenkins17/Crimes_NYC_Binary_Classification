# %%
import pandas as pd

# %%
df1 = pd.read_csv('df.csv')

# %%
df1.loc[df1["PREM_TYP_DESC"] == 'TRANSIT - NYC SUBWAY']
# Out:
#        Unnamed: 0 CMPLNT_FR_DT CMPLNT_FR_TM                      OFNS_DESC  \
# 0             172   06/09/2018     15:54:00                  GRAND LARCENY
# 1             226   03/01/2018     08:47:00                     SEX CRIMES
# 2             413   05/19/2018     12:25:00                        FORGERY
# 3             717   11/04/2018     00:00:00              DANGEROUS WEAPONS
# 4             844   01/18/2018     12:23:00  POSSESSION OF STOLEN PROPERTY
# ...           ...          ...          ...                            ...
# 20374     7824609   06/03/2018     01:20:00                        ROBBERY
# 20375     7824874   11/15/2018     20:00:00              DANGEROUS WEAPONS
# 20376     7825187   03/22/2018     08:15:00                     SEX CRIMES
# 20377     7825268   02/07/2018     03:45:00                  GRAND LARCENY
# 20378     7825279   11/09/2018     16:49:00                     SEX CRIMES
#
# ...

# %%
df1.PREM_TYP_DESC.value_counts()
# Out:
# TRANSIT - NYC SUBWAY          20139
# OTHER                            68
# TRANSIT FACILITY (OTHER)         52
# STREET                           51
# BUS (NYC TRANSIT)                17
# RESIDENCE - APT. HOUSE           10
# TRAMWAY                           4
# TUNNEL                            2
# GROCERY/BODEGA                    2
# RESIDENCE - PUBLIC HOUSING        2
# CHAIN STORE                       2
# HOMELESS SHELTER                  2
# CANDY STORE                       2
# RESTAURANT/DINER                  1
# COMMERCIAL BUILDING               1
# RESIDENCE-HOUSE                   1
# FAST FOOD                         1
# Name: PREM_TYP_DESC, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0               0
# CMPLNT_FR_DT             0
# CMPLNT_FR_TM             0
# OFNS_DESC               71
# PD_DESC                  0
# CRM_ATPT_CPTD_CD         0
# LAW_CAT_CD               0
# BORO_NM                 25
# LOC_OF_OCCUR_DESC    20324
# PREM_TYP_DESC           22
# PARKS_NM             20377
# HADEVELOPT           20379
# X_COORD_CD              26
# Y_COORD_CD              26
# SUSP_AGE_GROUP           0
# SUSP_SEX                18
# PATROL_BORO              0
# STATION_NAME             0
# VIC_AGE_GROUP            0
# VIC_RACE                 0
# VIC_SEX                  0
# CMPLNT_FR_DTTM           0
# dtype: int64
